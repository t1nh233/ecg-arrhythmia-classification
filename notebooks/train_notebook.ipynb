# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q "/content/drive/MyDrive/Colab_Workspace/ECG_Ready_To_Train.zip" -d "/content/ECG_Ready_To_Train"
# Out:
# replace /content/ECG_Ready_To_Train/src/config.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/constant.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/dataset.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/evaluate.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/models/cnn.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/models/gru.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/models/hybrid_model.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/predict.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/ECG_Ready_To_Train/src/p_preprocessing/bootstrapping.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %%
# %cd /content/ECG_Ready_To_Train
# !pip install -r requirements.txt
# Out:
# /content/ECG_Ready_To_Train
# ...

# %%
# !python main.py --mode tune
# Out:
# Khởi động hệ thống ECG. Chế độ: TUNE
# Đang nạp dữ liệu LÊN RAM một lần duy nhất cho Optuna...
# KHỞI ĐỘNG HỆ THỐNG OPTUNA HYPERPARAMETER TUNING...
# [I 2026-04-13 06:09:58,157] A new study created in memory with name: no-name-2483592a-3ceb-4c0b-905a-087315e68b4f
#
# Trial 0: LR=0.00171, WD=0.00003, Batch=64, GRU=64, Drop=0.29
# Bắt đầu quá trình huấn luyện...
# Dừng sớm tại Epoch 11. Không cải thiện trong 6 epochs.
# [I 2026-04-13 06:11:47,258] Trial 0 finished with value: 0.6908613258320497 and parameters: {'learning_rate': 0.0017144743509574104, 'weight_decay': 2.5553529031818062e-05, 'batch_size': 64, 'gru_hidden_size': 64, 'dropout_rate': 0.2890706894462297}. Best is trial 0 with value: 0.6908613258320497.
#
# Trial 1: LR=0.00352, WD=0.00091, Batch=64, GRU=64, Drop=0.29
# Bắt đầu quá trình huấn luyện...
# ...

# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: whaletrieuquoctinh (chieucuoctinh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !python main.py --mode train --run_name "Colab_T4_CNN_BiGRU_v4 (tuning param)"
# Out:
# Khởi động hệ thống ECG. Chế độ: TRAIN
#
# Phát hiện file cấu hình Optuna (./checkpoints/best_optuna_params.json).
# Đang tiến hành ghi đè config gốc để đạt độ chính xác tối đa...
#    + Đã cập nhật learning_rate: 0.00351510632591567
#    + Đã cập nhật weight_decay: 0.0009140734058280897
#    + Đã cập nhật batch_size: 64
#    + Đã cập nhật gru_hidden_size: 64
#    + Đã cập nhật dropout_rate: 0.2869167478049679
# --------------------------------------------------
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: whaletrieuquoctinh (chieucuoctinh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 7fr8lv8q (0.4s)
# wandb: Tracking run with wandb version 0.25.1
# ...

# %%
import os
from google.colab import files

print("Đang đóng gói toàn bộ thư mục checkpoints và outputs...")

# !zip -r -q ECG_Final_Results.zip checkpoints/ outputs/

if os.path.exists("ECG_Final_Results.zip"):
    print("Đóng gói thành công! Đang yêu cầu trình duyệt tải xuống...")
    print("Lưu ý: Đừng đóng tab Colab cho đến khi quá trình tải xuống hoàn tất trên trình duyệt nhé!")

    files.download("ECG_Final_Results.zip")
else:
    print("Có lỗi xảy ra trong quá trình nén file.")
# Out:
# Đang đóng gói toàn bộ thư mục checkpoints và outputs...
# Đóng gói thành công! Đang yêu cầu trình duyệt tải xuống...
# Lưu ý: Đừng đóng tab Colab cho đến khi quá trình tải xuống hoàn tất trên trình duyệt nhé!
